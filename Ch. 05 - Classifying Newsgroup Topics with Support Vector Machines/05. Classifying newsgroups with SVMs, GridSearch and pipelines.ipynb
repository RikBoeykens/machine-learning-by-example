# %% [markdown]
# Load all categories and clean data

# %%
from sklearn.datasets import fetch_20newsgroups
categories = None
data_train = fetch_20newsgroups(subset='train', categories=categories, random_state=42)
data_test = fetch_20newsgroups(subset='test', categories=categories, random_state=42)
def is_letter_only(word):
    for char in word:
        if not char.isalpha():
            return False
    return True

from nltk.corpus import names
all_names = set(names.words())
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
def clean_text(data):
    data_cleaned = []
    for doc in data:
        doc = doc.lower()
        doc_cleaned = ' '.join(lemmatizer.lemmatize(word) for word in doc.split() if is_letter_only(word) and word not in all_names)
        data_cleaned.append(doc_cleaned)
    return data_cleaned
cleaned_train = clean_text(data_train.data)
label_train = data_train.target
cleaned_test = clean_text(data_test.data)
label_test = data_test.target

# %% [markdown]
# Setup pipeline

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC

pipeline = Pipeline([
    ('tfidf', TfidfVectorizer(stop_words='english')),
    ('svc', LinearSVC()),
])

# %% [markdown]
# Setup hyperparameters
# parameters are tuned based on pipeline step name divided by __ to key

# %%
parameters_pipeline = {
    'tfidf__max_df': (0.25, 0.5, 1.0),
    'tfidf__max_features': (1000, None),
    'tfidf__sublinear_tf': (True, False),
    'tfidf__smooth_idf': (True, False),
    'svc__C': (0.3, 1, 3),
}

# %%
from sklearn.model_selection import GridSearchCV
import timeit

grid_search = GridSearchCV(pipeline, parameters_pipeline, n_jobs=1, cv=5, verbose=100)
start_time = timeit.default_timer()
grid_search.fit(cleaned_train, label_train)
print("--- %0.3fs seconds ---" % (timeit.default_timer() - start_time))

print(grid_search.best_params_)
print(grid_search.best_score_)

pipeline_best = grid_search.best_estimator_
accuracy = pipeline_best.score(cleaned_test, label_test)
print('The accuracy of 20-class classification is {0:.1f}%'.format(accuracy*100))
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.741, total=   1.7s
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    1.6s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.750, total=   1.6s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    3.2s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.752, total=   1.6s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    4.8s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.753, total=   1.7s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    6.5s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.751, total=   1.9s
# [Parallel(n_jobs=1)]: Done   5 out of   5 | elapsed:    8.4s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.731, total=   1.7s
# [Parallel(n_jobs=1)]: Done   6 out of   6 | elapsed:   10.1s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.744, total=   1.6s
# [Parallel(n_jobs=1)]: Done   7 out of   7 | elapsed:   11.7s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.745, total=   1.5s
# [Parallel(n_jobs=1)]: Done   8 out of   8 | elapsed:   13.2s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.749, total=   1.5s
# [Parallel(n_jobs=1)]: Done   9 out of   9 | elapsed:   14.7s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.743, total=   1.5s
# [Parallel(n_jobs=1)]: Done  10 out of  10 | elapsed:   16.2s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.741, total=   1.5s
# [Parallel(n_jobs=1)]: Done  11 out of  11 | elapsed:   17.8s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.750, total=   1.6s
# [Parallel(n_jobs=1)]: Done  12 out of  12 | elapsed:   19.3s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.752, total=   1.5s
# [Parallel(n_jobs=1)]: Done  13 out of  13 | elapsed:   20.8s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.753, total=   1.5s
# [Parallel(n_jobs=1)]: Done  14 out of  14 | elapsed:   22.3s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.751, total=   1.5s
# [Parallel(n_jobs=1)]: Done  15 out of  15 | elapsed:   23.8s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.731, total=   1.5s
# [Parallel(n_jobs=1)]: Done  16 out of  16 | elapsed:   25.3s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.744, total=   1.5s
# [Parallel(n_jobs=1)]: Done  17 out of  17 | elapsed:   26.8s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.745, total=   1.5s
# [Parallel(n_jobs=1)]: Done  18 out of  18 | elapsed:   28.3s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.749, total=   1.5s
# [Parallel(n_jobs=1)]: Done  19 out of  19 | elapsed:   29.8s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.744, total=   1.7s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:   31.5s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.894, total=   2.0s
# [Parallel(n_jobs=1)]: Done  21 out of  21 | elapsed:   33.6s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.894, total=   1.9s
# [Parallel(n_jobs=1)]: Done  22 out of  22 | elapsed:   35.4s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.895, total=   1.9s
# [Parallel(n_jobs=1)]: Done  23 out of  23 | elapsed:   37.4s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.897, total=   2.0s
# [Parallel(n_jobs=1)]: Done  24 out of  24 | elapsed:   39.4s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.901, total=   2.0s
# [Parallel(n_jobs=1)]: Done  25 out of  25 | elapsed:   41.4s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.887, total=   1.8s
# [Parallel(n_jobs=1)]: Done  26 out of  26 | elapsed:   43.3s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.884, total=   1.8s
# [Parallel(n_jobs=1)]: Done  27 out of  27 | elapsed:   45.1s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.888, total=   2.1s
# [Parallel(n_jobs=1)]: Done  28 out of  28 | elapsed:   47.2s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.889, total=   1.9s
# [Parallel(n_jobs=1)]: Done  29 out of  29 | elapsed:   49.2s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.897, total=   1.9s
# [Parallel(n_jobs=1)]: Done  30 out of  30 | elapsed:   51.1s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.895, total=   1.8s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:   52.9s remaining:    0.0s
# [CV] svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=0.3, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.893, total=   1.8s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed

# [CV] svc__C=0.3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=0.3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.896, total=   1.8s
# [CV] svc__C=0.3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=0.3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.896, total=   1.8s
# [CV] svc__C=0.3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=0.3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.901, total=   1.8s
# [CV] svc__C=0.3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=0.3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.889, total=   1.8s
# [CV] svc__C=0.3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=0.3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.886, total=   2.1s
# [CV] svc__C=0.3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=0.3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.892, total=   2.0s
# [CV] svc__C=0.3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=0.3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.891, total=   2.1s
# [CV] svc__C=0.3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=0.3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.898, total=   2.8s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.734, total=   2.2s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.747, total=   1.9s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.750, total=   1.6s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.746, total=   2.5s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.741, total=   2.1s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.726, total=   1.6s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.731, total=   2.0s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.738, total=   1.5s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.741, total=   1.5s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.731, total=   1.5s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.734, total=   1.9s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.747, total=   1.6s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.750, total=   2.1s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.745, total=   2.1s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.741, total=   1.9s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.726, total=   1.9s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.731, total=   1.6s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.738, total=   1.8s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.741, total=   1.9s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.731, total=   2.1s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.899, total=   2.9s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.901, total=   2.5s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.901, total=   2.1s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.901, total=   1.9s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.901, total=   2.0s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.894, total=   1.9s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.894, total=   2.1s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.889, total=   1.9s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.894, total=   1.9s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.901, total=   2.3s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.902, total=   2.0s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.900, total=   2.2s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.901, total=   2.4s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.903, total=   2.4s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.902, total=   2.0s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.893, total=   2.0s
# [CV] svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=1, tfidf__max_df=0.25, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.894, total=   2.0s
# ...
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.713, total=   1.7s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.717, total=   1.6s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.713, total=   1.6s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.896, total=   2.2s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.903, total=   2.2s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.899, total=   2.2s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.899, total=   2.2s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.902, total=   2.1s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.892, total=   2.2s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.893, total=   2.3s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.890, total=   2.2s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.896, total=   2.2s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.898, total=   2.2s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.897, total=   2.3s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.903, total=   2.4s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.900, total=   2.3s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.900, total=   2.2s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.902, total=   2.2s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.892, total=   2.2s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.894, total=   2.2s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.891, total=   2.2s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.896, total=   2.2s
# [CV] svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=0.5, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.899, total=   2.1s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.717, total=   1.8s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.724, total=   1.7s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.722, total=   1.8s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.724, total=   2.0s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.723, total=   1.9s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.713, total=   1.8s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.715, total=   1.7s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.713, total=   1.6s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.717, total=   1.6s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.713, total=   1.6s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.717, total=   1.6s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.724, total=   1.6s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.722, total=   1.7s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.724, total=   1.6s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.724, total=   1.6s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.713, total=   1.6s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.715, total=   1.6s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.713, total=   1.6s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.717, total=   1.6s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=1000, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.713, total=   1.8s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.896, total=   2.3s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.903, total=   2.3s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.899, total=   2.2s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.899, total=   2.2s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=True, score=0.901, total=   2.3s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.892, total=   2.3s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.893, total=   2.3s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.890, total=   2.3s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.896, total=   2.2s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=True, tfidf__sublinear_tf=False, score=0.898, total=   2.1s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.897, total=   2.2s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.903, total=   2.2s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.900, total=   2.2s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.900, total=   2.2s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=True, score=0.902, total=   2.4s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.892, total=   2.3s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.894, total=   2.6s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.891, total=   2.5s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.896, total=   2.3s
# [CV] svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False
# [CV]  svc__C=3, tfidf__max_df=1.0, tfidf__max_features=None, tfidf__smooth_idf=False, tfidf__sublinear_tf=False, score=0.899, total=   2.2s
# [Parallel(n_jobs=1)]: Done 360 out of 360 | elapsed: 11.2min finished
# --- 672.161s seconds ---
# {'svc__C': 1, 'tfidf__max_df': 0.5, 'tfidf__max_features': None, 'tfidf__smooth_idf': False, 'tfidf__sublinear_tf': True}
# 0.9033056390312887
# The accuracy of 20-class classification is 81.1%
